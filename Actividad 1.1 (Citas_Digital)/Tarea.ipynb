# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_excel('Citas_Digital.xlsx')
df
# Out:
#           BDC  Fecha Nombre Cliente  Telefono  Estatus de Lead  \
# 0        Saul    NaT      Guillermo        NaN     Finalizado
# 1        Saul    NaT        Roberto        NaN     Finalizado
# 2        Saul    NaT         Irving        NaN     Finalizado
# 3        Saul    NaT        Oswaldo        NaN          Venta
# 4        Saul    NaT        Rodrigo        NaN     Finalizado
# ...        ...   ...             ...       ...             ...
# 1048570    NaN   NaT             NaN       NaN             NaN
# 1048571    NaN   NaT             NaN       NaN             NaN
# 1048572    NaN   NaT             NaN       NaN             NaN
# 1048573    NaN   NaT             NaN       NaN             NaN
# 1048574    NaN   NaT             NaN       NaN             NaN
#
#         Potencial de compra  PDM  SDC  Venta Asesor Asignado  \
# 0                       0.9  1.0  0.0    0.0           Nancy
# 1                       0.4  0.0  0.0    0.0         Victor
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count    Dtype
# ---  ------                                    --------------    -----
#  0   BDC                                       673 non-null      object
#  1   Fecha                                     88 non-null       datetime64[us]
#  2   Nombre Cliente                            668 non-null      object
#  3   Telefono                                  2 non-null        str
#  4   Estatus de Lead                           654 non-null      object
#  5   Potencial de compra                       614 non-null      object
#  6   PDM                                       1048574 non-null  float64
#  7   SDC                                       1048573 non-null  float64
#  8   Venta                                     1048570 non-null  float64
#  9   Asesor Asignado                           656 non-null      str
# ...

# %%
#Paso 1 - Filtro por filas
filtro1 = df.iloc[0:673, :]
filtro1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   BDC                                       657 non-null    object
#  1   Fecha                                     72 non-null     datetime64[us]
#  2   Nombre Cliente                            652 non-null    object
#  3   Telefono                                  2 non-null      str
#  4   Estatus de Lead                           638 non-null    object
#  5   Potencial de compra                       599 non-null    object
#  6   PDM                                       672 non-null    float64
#  7   SDC                                       671 non-null    float64
#  8   Venta                                     668 non-null    float64
#  9   Asesor Asignado                           641 non-null    str
# ...

# %%
#Paso 2 - Filtro por columnas
filtro2 = filtro1.iloc[:, [0,1,2,4,5,6,7,8,9]]
filtro2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BDC                  657 non-null    object
#  1   Fecha                72 non-null     datetime64[us]
#  2   Nombre Cliente       652 non-null    object
#  3   Estatus de Lead      638 non-null    object
#  4   Potencial de compra  599 non-null    object
#  5   PDM                  672 non-null    float64
#  6   SDC                  671 non-null    float64
#  7   Venta                668 non-null    float64
#  8   Asesor Asignado      641 non-null    str
# dtypes: datetime64[us](1), float64(3), object(4), str(1)
# memory usage: 47.4+ KB

# %%
#Limpieza y conversión de Potencial de compra a float

filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("Ventas ","0", regex=False)
filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("%","", regex=False)
filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace('"',"", regex=False)
filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("&","", regex=False)

filtro2['Potencial de compra'] = filtro2['Potencial de compra'].astype(float)

filtro2.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 8
#       4 filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("%","", regex=False)
#       5 filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace('"',"", regex=False)
#       6 filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("&","", regex=False)
#       7
# ----> 8 filtro2['Potencial de compra'] = filtro2['Potencial de compra'].astype(float)
#       9
#      10 filtro2.info()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6529, in NDFrame.astype(self, dtype, copy, errors)
#    6525             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6526
#    6527         else:
#    6528             # else, only a single dtype is given
# ...

# %%
#Paso 3 - Convertir Potencial de compra a float
filtro2["Potencial de compra"] = filtro2["Potencial de compra"].astype(float)
filtro2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BDC                  657 non-null    object
#  1   Fecha                72 non-null     datetime64[us]
#  2   Nombre Cliente       652 non-null    object
#  3   Estatus de Lead      638 non-null    object
#  4   Potencial de compra  5 non-null      float64
#  5   PDM                  672 non-null    float64
#  6   SDC                  671 non-null    float64
#  7   Venta                668 non-null    float64
#  8   Asesor Asignado      641 non-null    str
# dtypes: datetime64[us](1), float64(4), object(3), str(1)
# memory usage: 47.4+ KB

# %%
#Limpieza y conversión de Potencial de compra a float

filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("Ventas ","0", regex=False)
filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("%","", regex=False)
filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("'","", regex=False)
filtro2['Potencial de compra'] = filtro2['Potencial de compra'].str.replace("&","", regex=False)

filtro2['Potencial de compra'] = filtro2['Potencial de compra'].astype(float)

filtro2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BDC                  657 non-null    object
#  1   Fecha                72 non-null     datetime64[us]
#  2   Nombre Cliente       652 non-null    object
#  3   Estatus de Lead      638 non-null    object
#  4   Potencial de compra  5 non-null      float64
#  5   PDM                  672 non-null    float64
#  6   SDC                  671 non-null    float64
#  7   Venta                668 non-null    float64
#  8   Asesor Asignado      641 non-null    str
# dtypes: datetime64[us](1), float64(4), object(3), str(1)
# memory usage: 47.4+ KB

# %%
#Paso 4 - Crear CSV General
filtro2.to_csv("Citas_Digital_General.csv", index=False)

# %%
df_general = pd.read_csv("Citas_Digital_General.csv")
df_general.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BDC                  657 non-null    str
#  1   Fecha                72 non-null     str
#  2   Nombre Cliente       652 non-null    str
#  3   Estatus de Lead      638 non-null    str
#  4   Potencial de compra  5 non-null      float64
#  5   PDM                  672 non-null    float64
#  6   SDC                  671 non-null    float64
#  7   Venta                668 non-null    float64
#  8   Asesor Asignado      641 non-null    str
# dtypes: float64(4), str(5)
# memory usage: 47.4 KB

# %%
#Se vuelve a leer el archivo general
df_general = pd.read_csv("Citas_Digital_General.csv")
df_general
# Out:
#          BDC        Fecha     Nombre Cliente  Estatus de Lead  \
# 0       Saul          NaN          Guillermo      Finalizado
# 1       Saul          NaN            Roberto      Finalizado
# 2       Saul          NaN             Irving      Finalizado
# 3       Saul          NaN            Oswaldo           Venta
# 4       Saul          NaN            Rodrigo      Finalizado
# ..        ...         ...                 ...             ...
# 668  Ignacio   2026-07-21  Carlos Balderrama          Activo
# 669  Ignacio   2026-07-21  Andrés Netzahuatl          Activo
# 670       Ana  2026-07-22         Arat Israel          Activo
# 671       Ana  2026-07-22     Maira Escalante         Activo
# 672  Ignacio   2026-07-22        Zaira Macip          Activo
#
#      Potencial de compra  PDM  SDC  Venta Asesor Asignado
# 0                    NaN  1.0  0.0    0.0           Nancy
# 1                    NaN  0.0  0.0    0.0         Victor
# ...

# %%
#Convertir la columna Fecha a formato fecha
df_general["Fecha"] = pd.to_datetime(df_general["Fecha"])

# %%
#ABRIL
abril_2025 = df_general[
    (df_general["Fecha"].dt.month == 4) &
    (df_general["Fecha"].dt.year == 2025)
]

abril_2025.to_csv("Abril_2025.csv", index=False)

# %%
#MAYO
mayo_2025 = df_general[
    (df_general["Fecha"].dt.month == 5) &
    (df_general["Fecha"].dt.year == 2025)
]

mayo_2025.to_csv("Mayo_2025.csv", index=False)

# %%
#JUNIO
junio_2025 = df_general[
    (df_general["Fecha"].dt.month == 6) &
    (df_general["Fecha"].dt.year == 2025)
]

junio_2025.to_csv("Junio_2025.csv", index=False)

# %%
#JULIO 
julio_2025 = df_general[
    (df_general["Fecha"].dt.month == 7) &
    (df_general["Fecha"].dt.year == 2025)
]

julio_2025.to_csv("Julio_2025.csv", index=False)

# %%
#AGOSTO 
agosto_2025 = df_general[
    (df_general["Fecha"].dt.month == 8) &
    (df_general["Fecha"].dt.year == 2025)
]

agosto_2025.to_csv("Agosto_2025.csv", index=False)

# %%
#SEPTIEMBRE
septiembre_2025 = df_general[
    (df_general["Fecha"].dt.month == 9) &
    (df_general["Fecha"].dt.year == 2025)
]

septiembre_2025.to_csv("Septiembre_2025.csv", index=False)

# %%
#OCTUBRE
octubre_2025 = df_general[
    (df_general["Fecha"].dt.month == 10) &
    (df_general["Fecha"].dt.year == 2025)
]

octubre_2025.to_csv("Octubre_2025.csv", index=False)

# %%
#NOVIEMBRE 
noviembre_2025 = df_general[
    (df_general["Fecha"].dt.month == 11) &
    (df_general["Fecha"].dt.year == 2025)
]

noviembre_2025.to_csv("Noviembre_2025.csv", index=False)

# %%
#DICIEMBRE
diciembre_2025 = df_general[
    (df_general["Fecha"].dt.month == 12) &
    (df_general["Fecha"].dt.year == 2025)
]

diciembre_2025.to_csv("Diciembre_2025.csv", index=False)

# %%
#ENERO 26
enero_2026 = df_general[
    (df_general["Fecha"].dt.month == 1) &
    (df_general["Fecha"].dt.year == 2026)
]

enero_2026.to_csv("Enero_2026.csv", index=False)

# %%
#FEBRERO 26
febrero_2026 = df_general[
    (df_general["Fecha"].dt.month == 2) &
    (df_general["Fecha"].dt.year == 2026)
]

febrero_2026.to_csv("Febrero_2026.csv", index=False)

# %%
#MARZO 26
marzo_2026 = df_general[
    (df_general["Fecha"].dt.month == 3) &
    (df_general["Fecha"].dt.year == 2026)
]

marzo_2026.to_csv("Marzo_2026.csv", index=False)

# %%
#ABRIL 26
abril_2026 = df_general[
    (df_general["Fecha"].dt.month == 4) &
    (df_general["Fecha"].dt.year == 2026)
]

abril_2026.to_csv("Abril_2026.csv", index=False)

# %%
#MAYO 26
mayo_2026 = df_general[
    (df_general["Fecha"].dt.month == 5) &
    (df_general["Fecha"].dt.year == 2026)
]

mayo_2026.to_csv("Mayo_2026.csv", index=False)

# %%
#JUNIO 26
junio_2026 = df_general[
    (df_general["Fecha"].dt.month == 6) &
    (df_general["Fecha"].dt.year == 2026)
]

junio_2026.to_csv("Junio_2026.csv", index=False)

# %%
#JULIO 26
julio_2026 = df_general[
    (df_general["Fecha"].dt.month == 7) &
    (df_general["Fecha"].dt.year == 2026)
]

julio_2026.to_csv("Julio_2026.csv", index=False)
